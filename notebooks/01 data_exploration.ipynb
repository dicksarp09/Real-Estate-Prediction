# %% [markdown]
# # Import Dependencies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Dickson\AI_ML Engineer Lab\ML System Pipeline\src\data\raw\real_estate.csv")

# %%
df.head()
# Out:
#    No  X1_transaction_date  X2_house_age  X3_distance_to_MRT_station  \
# 0   1          2013.498160     34.908086                  966.407998
# 1   2          2015.802857     26.804818                 2732.409690
# 2   3          2014.927976     15.476381                 4371.081888
# 3   4          2014.394634     40.689751                 3674.513188
# 4   5          2012.624075     34.236559                 4042.477682
#
#    X4_number_of_convenience_stores  X5_latitude  X6_longitude  \
# 0                                1    25.007911    121.582027
# 1                                5    25.045589    121.561605
# 2                                4    24.921589    121.443210
# 3                                9    25.037060    121.493322
# 4                                8    24.918374    121.563345
#
#    Y_house_price_of_unit_area
# 0                   27.573330
# 1                   34.488277
# 2                   30.592800
# 3                   38.287216
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   No                               500 non-null    int64
#  1   X1_transaction_date              500 non-null    float64
#  2   X2_house_age                     500 non-null    float64
#  3   X3_distance_to_MRT_station       500 non-null    float64
#  4   X4_number_of_convenience_stores  500 non-null    int64
#  5   X5_latitude                      500 non-null    float64
#  6   X6_longitude                     500 non-null    float64
#  7   Y_house_price_of_unit_area       500 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 31.4 KB

# %%
df.drop(columns=['No'], inplace=True)

# %%
df.describe()
# Out:
#        X1_transaction_date  X2_house_age  X3_distance_to_MRT_station  \
# count           500.000000    500.000000                  500.000000
# mean           2013.994247     24.097570                 2611.912703
# std               1.194754     14.274673                 1471.105017
# min            2012.020246      0.231601                   74.452906
# 25%            2012.965119     11.454962                 1244.078839
# 50%            2014.052655     23.591078                 2721.704763
# 75%            2015.024500     36.316841                 3897.851602
# max            2015.971859     49.985884                 4997.097943
#
#        X4_number_of_convenience_stores  X5_latitude  X6_longitude  \
# count                        500.00000   500.000000    500.000000
# mean                           4.80800    24.999561    121.504072
# std                            3.03076     0.058443      0.058399
# min                            0.00000    24.900038    121.400089
# ...

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
df.plot(kind='scatter' , x='X6_longitude', y='X5_latitude')
# Out:
# <Axes: xlabel='X6_longitude', ylabel='X5_latitude'>

# %%
df.plot(kind='scatter' , x='X6_longitude', y='X5_latitude', alpha=0.1)
# Out:
# <Axes: xlabel='X6_longitude', ylabel='X5_latitude'>

# %%
corr_matrix = df.corr()

# %%
corr_matrix['Y_house_price_of_unit_area'].sort_values(ascending=False)
# Out:
# Y_house_price_of_unit_area         1.000000
# X4_number_of_convenience_stores    0.499924
# X5_latitude                        0.081914
# X1_transaction_date                0.003439
# X6_longitude                      -0.021341
# X2_house_age                      -0.287869
# X3_distance_to_MRT_station        -0.632745
# Name: Y_house_price_of_unit_area, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 8))
sns.scatterplot(x="X2_house_age", y="Y_house_price_of_unit_area", data=df, ax=axes[0,0])
sns.scatterplot(x="X3_distance_to_MRT_station", y="Y_house_price_of_unit_area", data=df, ax=axes[0,1])
sns.scatterplot(x="X4_number_of_convenience_stores", y="Y_house_price_of_unit_area", data=df, ax=axes[0,2])
sns.scatterplot(x="X5_latitude", y="Y_house_price_of_unit_area", data=df, ax=axes[1,0])
sns.scatterplot(x="X6_longitude", y="Y_house_price_of_unit_area", data=df, ax=axes[1,1])
plt.tight_layout()
plt.show()
